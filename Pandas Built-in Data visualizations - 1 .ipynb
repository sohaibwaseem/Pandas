# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# ### Hist Plot

# %%
sn.set_style('darkgrid')
df1["A"].hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
df1.A.plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.A.plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Area Plot

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha = 0.4)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar Plot

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Line Plot

# %%
df1.plot.line()
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(figsize=(12,3), lw = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Scatter Plot

# %%
df1.plot.scatter(x = 'A', y = 'B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', s = df1['D']*100, cmap = 'plasma') # s use for size
# it will be an array with the size equal to x and y parameter.
# Out:
# G:\Anaconda 2\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# ### Box Plot

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(2000, 2), columns = ['E', 'F'])

# %%
df3.head()
# Out:
#           E         F
# 0  1.200480  1.476127
# 1  0.787138  1.458449
# 2  0.713776 -0.770015
# 3  1.083529 -1.189148
# 4  1.136873  0.552642

# %%
df3.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### HexaGonal Bin Plot

# %%
df3.plot.hexbin(x = 'E', y = 'F', gridsize = 25, cmap = 'Blues')
# Out:
# <AxesSubplot:xlabel='E', ylabel='F'>

# %% [markdown]
# ### Kernel Density Estimation plot (KDE)

# %%
df3.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
